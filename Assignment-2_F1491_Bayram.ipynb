# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
kill.groupby(["manner_of_death", "gender"])["age"].mean()
# Out:
# manner_of_death   gender
# shot              F         36.616162
#                   M         36.572798
# shot and Tasered  F         35.600000
#                   M         37.067485
# Name: age, dtype: float64

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
plt.figure(figsize=(9, 5))

sns.boxplot(x='gender', y="age", data=kill, hue="manner_of_death", orient='v');

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(10, 6))

sns.swarmplot(x='gender', y="age", data=kill, hue="manner_of_death", orient='v');

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = kill.city.value_counts()[:12]
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(city_freq.index, city_freq.values)
ax.set_ylabel("count")
ax.set_title("Mostdangerous cities", color="blue", fontsize=15)
ax.set_xticklabels(city_freq.index, rotation=45);

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill.state.value_counts()[:20]
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=state_freq.index, y=state_freq.values)
ax.set_title("Most dangerous states", color="blue", fontsize=15)
ax.set_xticklabels(state_freq.index, rotation=45)
fig.show()

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.countplot(x="state", data=kill, order=kill.state.value_counts().iloc[:20].index)
ax.set_title("Most dangerous states")
ax.set_xticklabels(state_freq.index, rotation=45)
ax.set_ylabel("count")
fig.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill["signs_of_mental_illness"].value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
fig, ax = plt.subplots()
ax = sns.barplot(x=illness.index, y=illness.values, data=kill)
ax.set_xlabel("signs_of_mental_illness")
ax.set_ylabel("count")
fig.show()

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill["threat_level"].value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
fig, ax = plt.subplots()
ax = sns.barplot(x=threads_freq.index, y=threads_freq.values)
ax.set_ylabel("count")
fig.show()

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill["flee"].value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
fig, ax = plt.subplots()
ax = sns.barplot(x=flee_freq.index, y=flee_freq.values)
ax.set_xlabel("flee")
ax.set_ylabel("count")
fig.show()
